# %%
import pandas as pd
import os

# %%
files = os.listdir("data")
df = pd.DataFrame()
for file in files:
    arq = os.path.join(os.getcwd(),"data", file)
    if "ipynb" not in arq:
        #print(arq)
        dfp = pd.read_csv(arq)
        df = pd.concat([df, dfp])

# %%
df2 = df.copy()
df2["date"] = pd.to_datetime(df[["year","month","day", "hour"]])

# %%
df2.drop(["No", "year","month","day", "hour", "wd"], axis=1, inplace=True)
df2.set_index(["station", "date"], drop=False, inplace=True)
df2.drop("date", axis=1, inplace=True)
df2.head()
# Out:
#                                   PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# station      date
# Aotizhongxin 2013-03-01 00:00:00    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
#              2013-03-01 01:00:00    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
#              2013-03-01 02:00:00    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
#              2013-03-01 03:00:00    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
#              2013-03-01 04:00:00    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#                                     PRES  DEWP  RAIN  WSPM       station
# station      date
# Aotizhongxin 2013-03-01 00:00:00  1023.0 -18.8   0.0   4.4  Aotizhongxin
#              2013-03-01 01:00:00  1023.2 -18.2   0.0   4.7  Aotizhongxin
#              2013-03-01 02:00:00  1023.5 -18.2   0.0   5.6  Aotizhongxin
#              2013-03-01 03:00:00  1024.5 -19.4   0.0   3.1  Aotizhongxin
#              2013-03-01 04:00:00  1025.2 -19.5   0.0   2.0  Aotizhongxin

# %%
df2 = df2.sort_index()
df2.tail(11)
# Out:
#                                    PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# station       date
# Wanshouxigong 2017-02-28 13:00:00    3.0   8.0  2.0   7.0  300.0  82.0  14.0
#               2017-02-28 14:00:00    3.0   6.0  NaN   5.0    NaN  82.0  14.6
#               2017-02-28 15:00:00   11.0  21.0  2.0   5.0  200.0   NaN  15.4
#               2017-02-28 16:00:00    6.0  20.0  3.0   NaN  200.0  80.0  14.9
#               2017-02-28 17:00:00   11.0  23.0  3.0  12.0  300.0  87.0  14.2
#               2017-02-28 18:00:00   11.0  30.0  2.0  16.0  300.0  82.0  13.4
#               2017-02-28 19:00:00   11.0  32.0  3.0  24.0  400.0  72.0  12.5
#               2017-02-28 20:00:00   13.0  32.0  3.0  41.0  500.0  50.0  11.6
#               2017-02-28 21:00:00   14.0  28.0  4.0  38.0  500.0  54.0  10.8
#               2017-02-28 22:00:00   12.0  23.0  4.0  30.0  400.0  59.0  10.5
#               2017-02-28 23:00:00   13.0  19.0  4.0  38.0  600.0  49.0   8.6
#
# ...

# %%
#df2.sort_values(by='date', ascending=True, inplace=True)
#df2.reset_index(inplace=True)
#df2.tail(10)

# %%
# from sklearn.preprocessing import LabelBinarizer
# station = LabelBinarizer().fit_transform(df2["station"])
# print(station)
# #df2["station"] = pd.Series(station)
# #df2 = encoder.fit_transform(df2)
# #df.tail()

# %%
# from sklearn.preprocessing import LabelEncoder
  
# le = LabelEncoder()
  
# df2['station']= le.fit_transform(df2['station'])

# %%
#station = pd.get_dummies(df2['station'], prefix='station')
#wd = pd.get_dummies(df2['wd'], prefix='wd')

# %%
#df3 = pd.concat([df2, wd, station], axis=0)
#df3 = pd.merge(left=df2,right=wd,left_index=True,right_index=True)
#df3 = pd.merge(left=df3,right=station,left_index=True,right_index=True)


#df3.drop(["wd", "station"], axis=1, inplace=True)

# %%
def train_test_split(data, column_name):
    size=int(len(data)*0.8)
    # for train data will be collected from each country's data which index is from 0-size (80%)
    x_train =data.drop(columns=[column_name]).iloc[0:size] 
    # for test data will be collected from each country's  data which index is from size to the end (20%)
    x_test = data.drop(columns=[column_name]).iloc[size:]
    y_train=data[column_name].iloc[0:size] 
    y_test=data[column_name].iloc[size:] 
    return x_train, x_test,y_train,y_test

# %%
df2[df2['station']=="Aotizhongxin"].head()
# Out:
#                                   PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# station      date
# Aotizhongxin 2013-03-01 00:00:00    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
#              2013-03-01 01:00:00    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
#              2013-03-01 02:00:00    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
#              2013-03-01 03:00:00    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
#              2013-03-01 04:00:00    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#                                     PRES  DEWP  RAIN  WSPM       station
# station      date
# Aotizhongxin 2013-03-01 00:00:00  1023.0 -18.8   0.0   4.4  Aotizhongxin
#              2013-03-01 01:00:00  1023.2 -18.2   0.0   4.7  Aotizhongxin
#              2013-03-01 02:00:00  1023.5 -18.2   0.0   5.6  Aotizhongxin
#              2013-03-01 03:00:00  1024.5 -19.4   0.0   3.1  Aotizhongxin
#              2013-03-01 04:00:00  1025.2 -19.5   0.0   2.0  Aotizhongxin

# %%
station=list(set(df2.station))
# loop each country_Region and split the data into train and test dataX_train=[]
X_train=[]
X_test=[]
Y_train=[]
Y_test=[]

for i in range(0,len(station)):
    df_p=df2[df2['station']==station[i]]    # applied the function I created above
    x_train, x_test,y_train,y_test=train_test_split(df_p, "RAIN")
    X_train.append(x_train)
    X_test.append(x_test)
    Y_train.append(y_train)
    Y_test.append(y_test)# concatenate each train data n X_train list and Y_train list respectively


X_train=pd.concat(X_train)
Y_train=pd.DataFrame(pd.concat(Y_train))# concatenate each test dataset in X_test list and Y_test list respectively
X_test=pd.concat(X_test)
Y_test=pd.DataFrame(pd.concat(Y_test))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
train_data=pd.DataFrame()
train_data[X_train.columns]=X_train
train_data[Y_train.columns]=Y_train
train_data['station']= encoder.fit_transform(train_data['station'])#combine X test and Y test as test data 
test_data=pd.DataFrame()
test_data[X_test.columns]=X_test
test_data[Y_test.columns]=Y_test
test_data['station']= encoder.fit_transform(test_data['station'])# using the function to obtian reshaped data

reframed_train = series_to_supervised(train_data)
reframed_test = series_to_supervised(test_data)

print("test_data shape: ", test_data.shape)
print("train_data shape: ", train_data.shape)
print("reframed_test shape: ", reframed_test.shape)
print("reframed_train shape: ", reframed_train.shape)
# Out:
# test_data shape:  (84156, 12)
# train_data shape:  (336612, 12)
# reframed_test shape:  (77598, 24)
# reframed_train shape:  (297223, 24)

# %%
def reshape_data(train,test):
    #Frame as supervised learning and drop all time t columns except
    reframed_train = series_to_supervised(train)
    reframed_test = series_to_supervised(test)
    print("reframed_test shape: ", reframed_test.shape)
    # split into train and test sets
    train= reframed_train.values
    test=reframed_test.values
    # split into input and outputs
    train_X, y_train = train[:, :-1], train[:, -1]
    test_X, y_test = test[:, :-1], test[:, -1]
    # reshape input to be 3D [samples, timesteps, features]
    x_train = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    
    x_test = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
    return x_train,x_test,y_train,y_test

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
#combine X train and Y train as train data 
train_data=pd.DataFrame()
train_data[X_train.columns]=X_train
train_data[Y_train.columns]=Y_train
train_data['station']= encoder.fit_transform(train_data['station'])#combine X test and Y test as test data 
test_data=pd.DataFrame()
test_data[X_test.columns]=X_test
test_data[Y_test.columns]=Y_test
test_data['station']= encoder.fit_transform(test_data['station'])# using the function to obtian reshaped data 
print("test_data shape: ", test_data.shape)
x_train,x_test,y_train,y_test=reshape_data(train_data,test_data)
# Out:
# test_data shape:  (84156, 12)
# reframed_test shape:  (77598, 24)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping

model = Sequential()
model.add(LSTM(128, activation='selu',input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
model.add(LSTM(100, activation='selu', return_sequences=True))
model.add(LSTM(92, activation='selu', return_sequences=True))
model.add(LSTM(64, activation='selu', return_sequences=True))
model.add(LSTM(24, activation='selu'))

model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(x_train, y_train, epochs=4, batch_size=50,  verbose=1, shuffle=False)
# Out:
# Epoch 1/4
# 5817/5817 [==============================] - 58s 10ms/step - loss: 0.0616
# Epoch 2/4
# 5817/5817 [==============================] - 45s 8ms/step - loss: 0.0591
# Epoch 3/4
# 5817/5817 [==============================] - 42s 7ms/step - loss: 0.0590
# Epoch 4/4
# 5817/5817 [==============================] - 48s 8ms/step - loss: 0.0589

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Loss')
plt.legend()
plt.show()

# %%
y_test_pre=model.predict(x_test)

# %%
x_test.shape
# Out:
# (76226, 1, 35)

# %%
q = X_test

# %%
q.head()
# Out:
#                               PM2.5   PM10  SO2   NO2      CO    O3  TEMP  \
# station  date
# Guanyuan 2016-05-12 19:00:00   12.0   34.0  2.0  42.0   400.0  62.0  20.3
#          2016-05-12 20:00:00   21.0   69.0  2.0  71.0   500.0  25.0  17.4
#          2016-05-12 21:00:00   28.0   83.0  2.0  85.0   900.0   2.0  14.7
#          2016-05-12 22:00:00   39.0  105.0  2.0  80.0  1400.0   2.0  12.8
#          2016-05-12 23:00:00   40.0   80.0  2.0  81.0  1600.0   2.0  11.2
#
#                                 PRES  DEWP  WSPM   station
# station  date
# Guanyuan 2016-05-12 19:00:00  1011.7  -5.6   2.2  Guanyuan
#          2016-05-12 20:00:00  1012.6   0.1   0.6  Guanyuan
#          2016-05-12 21:00:00  1013.8   1.6   0.5  Guanyuan
#          2016-05-12 22:00:00  1014.4   2.6   0.0  Guanyuan
#          2016-05-12 23:00:00  1014.6   4.6   0.4  Guanyuan

# %%
q.reset_index(level="date", drop=True).head()
# Out:
#           PM2.5   PM10  SO2   NO2      CO    O3  TEMP    PRES  DEWP  WSPM  \
# station
# Guanyuan   12.0   34.0  2.0  42.0   400.0  62.0  20.3  1011.7  -5.6   2.2
# Guanyuan   21.0   69.0  2.0  71.0   500.0  25.0  17.4  1012.6   0.1   0.6
# Guanyuan   28.0   83.0  2.0  85.0   900.0   2.0  14.7  1013.8   1.6   0.5
# Guanyuan   39.0  105.0  2.0  80.0  1400.0   2.0  12.8  1014.4   2.6   0.0
# Guanyuan   40.0   80.0  2.0  81.0  1600.0   2.0  11.2  1014.6   4.6   0.4
#
#            station
# station
# Guanyuan  Guanyuan
# Guanyuan  Guanyuan
# Guanyuan  Guanyuan
# Guanyuan  Guanyuan
# Guanyuan  Guanyuan

# %%
X_test.shape
# Out:
# (84156, 11)

# %%
y_test_pre.shape
# Out:
# (76226, 1)

# %%
q.head()
# Out:
#    PM2.5   PM10  SO2   NO2      CO    O3  TEMP    PRES  DEWP  WSPM   station
# 0   12.0   34.0  2.0  42.0   400.0  62.0  20.3  1011.7  -5.6   2.2  Guanyuan
# 1   21.0   69.0  2.0  71.0   500.0  25.0  17.4  1012.6   0.1   0.6  Guanyuan
# 2   28.0   83.0  2.0  85.0   900.0   2.0  14.7  1013.8   1.6   0.5  Guanyuan
# 3   39.0  105.0  2.0  80.0  1400.0   2.0  12.8  1014.4   2.6   0.0  Guanyuan
# 4   40.0   80.0  2.0  81.0  1600.0   2.0  11.2  1014.6   4.6   0.4  Guanyuan

# %%
pa=pd.DataFrame()
pa['Date']=X_test.reset_index(level="date").date.iloc[1:-1]
pa['Prediction']=[i[0] for i in y_test_pre][1:] 
pa['Actual Values']=y_test[:-1]
pa.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-f56404f5115d> in <module>
#       1 pa=pd.DataFrame()
#       2 pa['Date']=X_test.reset_index(level="date").date.iloc[1:-1]
# ----> 3 pa['Prediction']=[i[0] for i in y_test_pre][1:]
#       4 pa['Actual Values']=y_test[:-1]
#       5 pa.head()
#
# C:\Miniconda3\envs\paneldata\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# C:\Miniconda3\envs\paneldata\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
# ...

# %%
plt.figure(figsize=(20,10))
pa.groupby('Date')['Prediction'].sum().plot(kind='line',label='prediction',color='red',alpha=1)
pa.groupby("Date")['Actual Values'].sum().plot(kind='line',label='actual values',color='blue',alpha=0.4)
plt.xticks(rotation=90,size=20)
plt.yticks(size=20)

plt.ylabel('Fatalities',fontsize=20)
plt.xlabel('Date',fontsize=20)
plt.title('Predicted Values VS Acutal Values - Fatalities',fontsize=20)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-e1a91e5d72b7> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 pa.groupby('Date')['Prediction'].sum().plot(kind='line',label='prediction',color='red',alpha=1)
#       3 pa.groupby("Date")['Actual Values'].sum().plot(kind='line',label='actual values',color='blue',alpha=0.4)
#       4 plt.xticks(rotation=90,size=20)
#       5 plt.yticks(size=20)
#
# NameError: name 'pa' is not defined
